# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('master.csv',index_col=0)

# %%
df.head()
# Out:
#          year     sex          age  suicides_no  population  \
# country
# Albania  1987    male  15-24 years           21      312900
# Albania  1987    male  35-54 years           16      308000
# Albania  1987  female  15-24 years           14      289700
# Albania  1987    male    75+ years            1       21800
# Albania  1987    male  25-34 years            9      274300
#
#          suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# country
# Albania               6.71  Albania1987           NaN      2,156,624,900
# Albania               5.19  Albania1987           NaN      2,156,624,900
# Albania               4.83  Albania1987           NaN      2,156,624,900
# Albania               4.59  Albania1987           NaN      2,156,624,900
# Albania               3.28  Albania1987           NaN      2,156,624,900
#
#          gdp_per_capita ($)       generation
# country
# Albania                 796     Generation X
# ...

# %%
df.shape[1]#columns
# Out:
# 11

# %%
df.shape[0]#rows
# Out:
# 27820

# %%
df.count()
# Out:
# year                  27820
# sex                   27820
# age                   27820
# suicides_no           27820
# population            27820
# suicides/100k pop     27820
# country-year          27820
# HDI for year           8364
#  gdp_for_year ($)     27820
# gdp_per_capita ($)    27820
# generation            27820
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27820 entries, Albania to Uzbekistan
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   year                27820 non-null  int64
#  1   sex                 27820 non-null  object
#  2   age                 27820 non-null  object
#  3   suicides_no         27820 non-null  int64
#  4   population          27820 non-null  int64
#  5   suicides/100k pop   27820 non-null  float64
#  6   country-year        27820 non-null  object
#  7   HDI for year        8364 non-null   float64
#  8    gdp_for_year ($)   27820 non-null  object
#  9   gdp_per_capita ($)  27820 non-null  int64
#  10  generation          27820 non-null  object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 2.5+ MB

# %%
df.columns
# Out:
# Index(['year', 'sex', 'age', 'suicides_no', 'population', 'suicides/100k pop',
#        'country-year', 'HDI for year', ' gdp_for_year ($) ',
#        'gdp_per_capita ($)', 'generation'],
#       dtype='object')

# %%
df.transpose()
# Out:
# country                   Albania        Albania        Albania  \
# year                         1987           1987           1987
# sex                          male           male         female
# age                   15-24 years    35-54 years    15-24 years
# suicides_no                    21             16             14
# population                 312900         308000         289700
# suicides/100k pop            6.71           5.19           4.83
# country-year          Albania1987    Albania1987    Albania1987
# HDI for year                  NaN            NaN            NaN
#  gdp_for_year ($)   2,156,624,900  2,156,624,900  2,156,624,900
# gdp_per_capita ($)            796            796            796
# generation           Generation X         Silent   Generation X
#
# country                     Albania        Albania          Albania  \
# year                           1987           1987             1987
# ...

# %%
i=0
while i<10:
    print(len(df.transpose().iloc[i].unique()))
    i=i+1
    
#number of unique values for each column
# Out:
# 32
# 2
# 6
# 2084
# 25564
# 5298
# 2321
# 306
# 2321
# 2233

# %%
df.dropna()#ans 8364
# Out:
#             year     sex          age  suicides_no  population  \
# country
# Albania     1995    male  25-34 years           13      232900
# Albania     1995    male  55-74 years            9      178000
# Albania     1995  female    75+ years            2       40800
# Albania     1995  female  15-24 years           13      283500
# Albania     1995    male  15-24 years           11      241200
# ...          ...     ...          ...          ...         ...
# Uzbekistan  2014  female  35-54 years          107     3620833
# Uzbekistan  2014  female    75+ years            9      348465
# Uzbekistan  2014    male   5-14 years           60     2762158
# Uzbekistan  2014  female   5-14 years           44     2631600
# Uzbekistan  2014  female  55-74 years           21     1438935
#
#             suicides/100k pop    country-year  HDI for year  \
# country
# Albania                  5.58     Albania1995         0.619
# Albania                  5.06     Albania1995         0.619
# ...

# %%
df.dropna(axis=1)#only HDI has mssing entries.number=27820-8364=19456
# Out:
#             year     sex          age  suicides_no  population  \
# country
# Albania     1987    male  15-24 years           21      312900
# Albania     1987    male  35-54 years           16      308000
# Albania     1987  female  15-24 years           14      289700
# Albania     1987    male    75+ years            1       21800
# Albania     1987    male  25-34 years            9      274300
# ...          ...     ...          ...          ...         ...
# Uzbekistan  2014  female  35-54 years          107     3620833
# Uzbekistan  2014  female    75+ years            9      348465
# Uzbekistan  2014    male   5-14 years           60     2762158
# Uzbekistan  2014  female   5-14 years           44     2631600
# Uzbekistan  2014  female  55-74 years           21     1438935
#
#             suicides/100k pop    country-year  gdp_for_year ($)   \
# country
# Albania                  6.71     Albania1987      2,156,624,900
# ...

# %%
df.count()
# Out:
# year                  27820
# sex                   27820
# age                   27820
# suicides_no           27820
# population            27820
# suicides/100k pop     27820
# country-year          27820
# HDI for year           8364
#  gdp_for_year ($)     27820
# gdp_per_capita ($)    27820
# generation            27820
# dtype: int64
